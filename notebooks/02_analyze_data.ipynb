# %%
import re
from collections import defaultdict

import pandas as pd
import sentencepiece as spm
from uralicNLP import uralicApi

# %%
data = pd.read_csv("./data/lexeme_stems.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28283 entries, 0 to 28282
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lexeme     28283 non-null  object
#  1   language   28283 non-null  object
#  2   pos        28283 non-null  object
#  3   stem_text  28283 non-null  object
#  4   contlex    28283 non-null  object
# dtypes: object(5)
# memory usage: 1.1+ MB

# %%
data["contlex"].value_counts()
# Out:
# contlex
# N_SAJOS                   2865
# N_SAJOS_USESPELLNOSUGG    1640
# N_MAINSTUMMUSH            1546
# N_SAJOS_ERRORTH           1417
# ADV_                       872
#                           ...
# A_PUEAQRDES                  1
# V_JOAQTTED_ERRORTH           1
# NUM_KUEQHTT                  1
# NUM_TAQHTT                   1
# N_SIYKKK_SEMGAME             1
# Name: count, Length: 1233, dtype: int64

# %%
len(data["contlex"].unique())
# Out:
# 1233

# %%
data[data["contlex"] == "V_LAEULLAD"]
# Out:
#          lexeme language pos           stem_text     contlex
# 4       läukkad      sms   V         lä%^1VOWukk  V_LAEULLAD
# 413      äinnad      sms   V          ä%^1VOWinn  V_LAEULLAD
# 760    njõikkad      sms   V  njõ%^1VOWi%{ʹØ%}kk  V_LAEULLAD
# 1034    härvvad      sms   V         hä%^1VOWrvv  V_LAEULLAD
# 1776    häuddad      sms   V         hä%^1VOWudd  V_LAEULLAD
# 1958     åimmad      sms   V          å%^1VOWimm  V_LAEULLAD
# 2251     äiddad      sms   V          ä%^1VOWidd  V_LAEULLAD
# 2717    tåiddad      sms   V         tå%^1VOWidd  V_LAEULLAD
# 2884    läuddad      sms   V         lä%^1VOWudd  V_LAEULLAD
# 3331    näuddad      sms   V         nä%^1VOWudd  V_LAEULLAD
# 4392    räiggad      sms   V         rä%^1VOWigg  V_LAEULLAD
# 6244    čåujjad      sms   V         čå%^1VOWujj  V_LAEULLAD
# 6988    håiddad      sms   V         hå%^1VOWidd  V_LAEULLAD
# 7232    läittad      sms   V         lä%^1VOWitt  V_LAEULLAD
# 7483    läullad      sms   V         lä%^1VOWull  V_LAEULLAD
# 7690   njäuggad      sms   V        njä%^1VOWugg  V_LAEULLAD
# 8770    käinnad      sms   V         kä%^1VOWinn  V_LAEULLAD
# 10230   käiddad      sms   V         kä%^1VOWidd  V_LAEULLAD
# 10659   läivvad      sms   V         lä%^1VOWivv  V_LAEULLAD
# 13511   kåikkad      sms   V         kå%^1VOWikk  V_LAEULLAD
# 13815  ǩeunnjad      sms   V        ǩe%^1VOWunnj  V_LAEULLAD
# 16932  šmoiggad      sms   V        šmo%^1VOWigg  V_LAEULLAD
# 17554   nåiddad      sms   V         nå%^1VOWidd  V_LAEULLAD
# 17680    äiggad      sms   V          ä%^1VOWigg  V_LAEULLAD
# 18115   čärŋŋad      sms   V         čä%^1VOWrŋŋ  V_LAEULLAD
# 18826   lâuŋŋad      sms   V         lâ%^1VOWuŋŋ  V_LAEULLAD
# 19056   säurrad      sms   V         sä%^1VOWurr  V_LAEULLAD
# 22824  stäullad      sms   V        stä%^1VOWull  V_LAEULLAD
# 25289   pärddad      sms   V         pä%^1VOWrdd  V_LAEULLAD
# 25449    åiggad      sms   V          å%^1VOWigg  V_LAEULLAD
# 26656   poskkad      sms   V         po%^1VOWskk  V_LAEULLAD
# 27158   päinnad      sms   V         pä%^1VOWinn  V_LAEULLAD
# 27773   kåittad      sms   V         kå%^1VOWitt  V_LAEULLAD
# 27801   läuggad      sms   V         lä%^1VOWugg  V_LAEULLAD
# 27911   pelggad      sms   V         pe%^1VOWlgg  V_LAEULLAD
# 27978   šäiggad      sms   V         šä%^1VOWigg  V_LAEULLAD
# 28030   tåimmad      sms   V         tå%^1VOWimm  V_LAEULLAD

# %% [markdown]
# ## Prepare data for BPE

# %%
data["pos"].unique()
# Out:
# array(['V', 'N', 'A', 'Adv', 'CS', 'CC', 'Adp', 'Pcle', 'Det', 'Interj',
#        'Num', 'Pron', 'Po'], dtype=object)

# %%
selected_pos_data = data[data['pos'].isin(['N', 'V'])]

# %%
pattern = re.compile(r'^[A-Z]+_.+')

filtered_data = selected_pos_data[selected_pos_data['contlex'].apply(lambda x: bool(pattern.match(x)))]

# %%
filtered_data
# Out:
#                    lexeme language pos                          stem_text  \
# 0                taibsted      sms   V                           taaibâst
# 1                   ääʹll      sms   N                         ää%{ʹØ%}ll
# 2          njââʹllvaaldõs      sms   N         njââʹllvaaldõ%^1VOW%{ʹØ%}s
# 4                 läukkad      sms   V                        lä%^1VOWukk
# 5             laukkõõllâd      sms   V                    laukkõõ%{ʹØ%}ll
# ...                   ...      ...  ..                                ...
# 28278      jieʹllidåhttar      sms   N                    jieʹlli#dåhttar
# 28279            nuõrrǥaž      sms   N                             nuõrrǥ
# 28280            looǥǥâlm      sms   N                           looǥǥâlm
# 28281  paneelsaǥstõõllmõš      sms   N  panẹẹl#saǥ»stõõll»mõ%^1VOW%{ʹØ%}š
# 28282     pueʹreemeʹtǩǩõs      sms   N       pueʹreem#eʹtǩǩõ%^1VOW%{ʹØ%}s
#
#              contlex
# 0         V_MAINSTED
# 1           N_SAAQMM
# 2            N_SAJOS
# 4         V_LAEULLAD
# 5      V_LAUKKOOLLYD
# ...              ...
# 28278        N_AANAR
# 28279     N_MEERSAZH
# 28280     N_COOGGYLM
# 28281        N_SAJOS
# 28282        N_SAJOS
#
# [24039 rows x 5 columns]

# %%
miniparadigms = {
    "V": ["V+Ind+Prs+ConNeg", "V+Ind+Prs+Sg3", "V+Ind+Prt+Sg1", "V+Ind+Prt+Sg3", "V+Inf", "V+Ind+Prs+Sg1", "V+Pass+PrfPrc", "V+Ind+Prs+Pl3", "V+Imprt+Sg3", "V+Imprt+Pl3"],
    "N": ["N+Sg+Loc", "N+Sg+Ill", "N+Pl+Gen", "N+Sg+Nom", "N+Sg+Gen", "N+Sg+Loc+PxSg3", "N+Ess", "N+Der/Dimin+N+Sg+Nom", "N+Der/Dimin+N+Sg+Gen", "N+Sg+Ill+PxSg1"],
    # "A": ["A+Attr"],
}

# %%
for index, row in filtered_data.iterrows():
    lexeme = row['lexeme']
    pos = row['pos']
    all_forms = []
    if pos in miniparadigms:
        forms = miniparadigms[pos]
        for form in forms:
            result = uralicApi.generate(f"{lexeme}+{form}", "sms", dictionary_forms=False)
            if result:
                all_forms.extend([_f[0] for _f in result])
        
        filtered_data.loc[index, "forms"] = " ".join([_f for _f in all_forms])

# %%
filtered_data.to_csv('./data/lexeme_data_with_forms_3.csv', index=False)

# %%
with open('./data/bpe_lexeme_text_3.txt', 'w', encoding='utf-8') as f:
    f.write('\n'.join([f"{row['lexeme']} {row['forms']}" for _, row in filtered_data.iterrows()]))

# %%
spm.SentencePieceTrainer.Train('--input=./data/bpe_lexeme_text_3.txt --model_prefix=skolt_bpe_3 --vocab_size=2000 --model_type=bpe')
# Out:
# sentencepiece_trainer.cc(178) LOG(INFO) Running command: --input=./data/bpe_lexeme_text_3.txt --model_prefix=skolt_bpe_3 --vocab_size=2000 --model_type=bpe
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: ./data/bpe_lexeme_text_3.txt
#   input_format:
#   model_prefix: skolt_bpe_3
#   model_type: BPE
#   vocab_size: 2000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(353) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(185) LOG(INFO) Loading corpus: ./data/bpe_lexeme_text_3.txt
# trainer_interface.cc(409) LOG(INFO) Loaded all 24039 sentences
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(430) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(539) LOG(INFO) all chars count=4323277
# trainer_interface.cc(550) LOG(INFO) Done: 99.9839% characters are covered.
# trainer_interface.cc(560) LOG(INFO) Alphabet size=40
# trainer_interface.cc(561) LOG(INFO) Final character coverage=0.999839
# trainer_interface.cc(592) LOG(INFO) Done! preprocessed 24039 sentences.
# trainer_interface.cc(598) LOG(INFO) Tokenizing input sentences with whitespace: 24039
# trainer_interface.cc(609) LOG(INFO) Done! 221762
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=89849 min_freq=13
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=26638 size=20 all=1942 active=1846 piece=▁t
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15908 size=40 all=2833 active=2737 piece=▁j
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11348 size=60 all=3966 active=3870 piece=âž
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7116 size=80 all=5200 active=5104 piece=žže
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5050 size=100 all=6257 active=6161 piece=âtt
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5015 min_freq=546
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3470 size=120 all=7589 active=2262 piece=es
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3259 size=140 all=8643 active=3316 piece=lm
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2896 size=160 all=9875 active=4548 piece=ummšasan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2360 size=180 all=11370 active=6043 piece=▁čuõ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2028 size=200 all=12523 active=7196 piece=▁vä
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2017 min_freq=425
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1888 size=220 all=13539 active=1982 piece=ad
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1657 size=240 all=14823 active=3266 piece=▁sää
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1494 size=260 all=15886 active=4329 piece=vt
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1357 size=280 all=16679 active=5122 piece=▁pâ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1288 size=300 all=17693 active=6136 piece=raa
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1288 min_freq=349
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1226 size=320 all=18585 active=1810 piece=▁rä
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1160 size=340 all=19854 active=3079 piece=čuõ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1098 size=360 all=20721 active=3946 piece=la
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1023 size=380 all=21631 active=4856 piece=už
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=964 size=400 all=22486 active=5711 piece=▁si
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=963 min_freq=280
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=903 size=420 all=23736 active=2353 piece=▁mädd
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=853 size=440 all=24881 active=3498 piece=rnn
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=799 size=460 all=26049 active=4666 piece=dstes
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=754 size=480 all=26794 active=5411 piece=▁jåå
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=728 size=500 all=27571 active=6188 piece=lo
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=725 min_freq=205
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=694 size=520 all=28408 active=2168 piece=▁lââ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=667 size=540 all=29413 active=3173 piece=âvv
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=643 size=560 all=30552 active=4312 piece=▁lå
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=619 size=580 all=31104 active=4864 piece=šǩǩ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=591 size=600 all=32058 active=5818 piece=mää
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=588 min_freq=161
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=565 size=620 all=32988 active=2472 piece=▁čõ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=536 size=640 all=34006 active=3490 piece=▁ruä
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=512 size=660 all=34737 active=4221 piece=koo
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=499 size=680 all=35617 active=5101 piece=lu
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=483 size=700 all=36609 active=6093 piece=raž
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=483 min_freq=133
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=464 size=720 all=37216 active=2371 piece=▁sie
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=449 size=740 all=37779 active=2934 piece=stâ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=438 size=760 all=38745 active=3900 piece=šem
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=428 size=780 all=39511 active=4666 piece=▁tiudd
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=410 size=800 all=40225 active=5380 piece=ren
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=410 min_freq=116
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=401 size=820 all=41064 active=2808 piece=▁nje
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=388 size=840 all=41839 active=3583 piece=lb
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=379 size=860 all=42451 active=4195 piece=lstõõll
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq